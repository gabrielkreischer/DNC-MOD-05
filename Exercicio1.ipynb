# %%
# %pip install sidetable
# %pip install pandas
# %pip install missingno

# %pip install --upgrade numba
# %pip install --force-reinstall pandas-profiling
# %pip install pydantic-settings
# %pip install pydantic==1.10.8
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sidetable in c:\users\gabri\appdata\roaming\python\python312\site-packages (0.9.1)
# Requirement already satisfied: pandas>=1.0 in d:\programdata\anaconda3\lib\site-packages (from sidetable) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in d:\programdata\anaconda3\lib\site-packages (from pandas>=1.0->sidetable) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\programdata\anaconda3\lib\site-packages (from pandas>=1.0->sidetable) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\programdata\anaconda3\lib\site-packages (from pandas>=1.0->sidetable) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\programdata\anaconda3\lib\site-packages (from pandas>=1.0->sidetable) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0->sidetable) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in d:\programdata\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in d:\programdata\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\programdata\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\programdata\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\programdata\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: missingno in c:\users\gabri\appdata\roaming\python\python312\site-packages (0.5.2)
# Requirement already satisfied: numpy in d:\programdata\anaconda3\lib\site-packages (from missingno) (1.26.4)
# Requirement already satisfied: matplotlib in d:\programdata\anaconda3\lib\site-packages (from missingno) (3.8.4)
# Requirement already satisfied: scipy in d:\programdata\anaconda3\lib\site-packages (from missingno) (1.13.1)
# Requirement already satisfied: seaborn in d:\programdata\anaconda3\lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\programdata\anaconda3\lib\site-packages (from matplotlib->missingno) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\programdata\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\programdata\anaconda3\lib\site-packages (from matplotlib->missingno) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\programdata\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\programdata\anaconda3\lib\site-packages (from matplotlib->missingno) (23.2)
# Requirement already satisfied: pillow>=8 in d:\programdata\anaconda3\lib\site-packages (from matplotlib->missingno) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\programdata\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\programdata\anaconda3\lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in d:\programdata\anaconda3\lib\site-packages (from seaborn->missingno) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in d:\programdata\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\programdata\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numba in d:\programdata\anaconda3\lib\site-packages (0.59.1)
# Collecting numba
#   Using cached numba-0.60.0-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba)
#   Using cached llvmlite-0.43.0-cp312-cp312-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: numpy<2.1,>=1.22 in d:\programdata\anaconda3\lib\site-packages (from numba) (1.26.4)
# Using cached numba-0.60.0-cp312-cp312-win_amd64.whl (2.7 MB)
# Using cached llvmlite-0.43.0-cp312-cp312-win_amd64.whl (28.1 MB)
# Installing collected packages: llvmlite, numba
# Successfully installed llvmlite-0.43.0 numba-0.60.0
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas-profiling
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Using cached joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting scipy>=1.4.1 (from pandas-profiling)
#   Using cached scipy-1.14.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 (from pandas-profiling)
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting matplotlib>=3.2.0 (from pandas-profiling)
#   Using cached matplotlib-3.9.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting pydantic>=1.8.1 (from pandas-profiling)
#   Using cached pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
# Collecting PyYAML>=5.0.0 (from pandas-profiling)
#   Using cached PyYAML-6.0.1-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting jinja2>=2.11.1 (from pandas-profiling)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting markupsafe~=2.1.1 (from pandas-profiling)
#   Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Using cached visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Collecting numpy>=1.16.0 (from pandas-profiling)
#   Using cached numpy-2.0.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting htmlmin>=0.1.12 (from pandas-profiling)
#   Using cached htmlmin-0.1.12-py3-none-any.whl
# Collecting missingno>=0.4.2 (from pandas-profiling)
#   Using cached missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Collecting phik>=0.11.1 (from pandas-profiling)
#   Using cached phik-0.12.4-cp312-cp312-win_amd64.whl.metadata (5.6 kB)
# Collecting tangled-up-in-unicode==0.2.0 (from pandas-profiling)
#   Using cached tangled_up_in_unicode-0.2.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting requests>=2.24.0 (from pandas-profiling)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tqdm>=4.48.2 (from pandas-profiling)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Collecting seaborn>=0.10.1 (from pandas-profiling)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting multimethod>=1.4 (from pandas-profiling)
#   Using cached multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Collecting attrs>=19.3.0 (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting networkx>=2.4 (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling)
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting imagehash (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting Pillow (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.2.0->pandas-profiling)
#   Using cached contourpy-1.2.1-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.2.0->pandas-profiling)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.2.0->pandas-profiling)
#   Using cached fonttools-4.53.1-cp312-cp312-win_amd64.whl.metadata (165 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.2.0->pandas-profiling)
#   Using cached kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Collecting packaging>=20.0 (from matplotlib>=3.2.0->pandas-profiling)
#   Using cached packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.2.0->pandas-profiling)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting python-dateutil>=2.7 (from matplotlib>=3.2.0->pandas-profiling)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting annotated-types>=0.4.0 (from pydantic>=1.8.1->pandas-profiling)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic>=1.8.1->pandas-profiling)
#   Using cached pydantic_core-2.20.1-cp312-none-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-extensions>=4.6.1 (from pydantic>=1.8.1->pandas-profiling)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.24.0->pandas-profiling)
#   Using cached charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.24.0->pandas-profiling)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.24.0->pandas-profiling)
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.24.0->pandas-profiling)
#   Using cached certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Collecting colorama (from tqdm>=4.48.2->pandas-profiling)
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling)
#   Using cached six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting PyWavelets (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling)
#   Using cached pywavelets-1.6.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Using cached tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
# Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached joblib-1.1.1-py2.py3-none-any.whl (309 kB)
# Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Using cached matplotlib-3.9.1-cp312-cp312-win_amd64.whl (8.0 MB)
# Using cached missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Using cached multimethod-1.12-py3-none-any.whl (10 kB)
# Using cached numpy-2.0.1-cp312-cp312-win_amd64.whl (16.3 MB)
# Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached phik-0.12.4-cp312-cp312-win_amd64.whl (666 kB)
# Using cached pydantic-2.8.2-py3-none-any.whl (423 kB)
# Using cached pydantic_core-2.20.1-cp312-none-win_amd64.whl (1.9 MB)
# Using cached PyYAML-6.0.1-cp312-cp312-win_amd64.whl (138 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached scipy-1.14.0-cp312-cp312-win_amd64.whl (44.5 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached certifi-2024.7.4-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
# Using cached contourpy-1.2.1-cp312-cp312-win_amd64.whl (189 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.53.1-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Using cached packaging-24.1-py3-none-any.whl (53 kB)
# Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Using cached pywavelets-1.6.0-cp312-cp312-win_amd64.whl (4.2 MB)
# Installing collected packages: pytz, htmlmin, urllib3, tzdata, typing-extensions, tangled-up-in-unicode, six, PyYAML, pyparsing, Pillow, packaging, numpy, networkx, multimethod, markupsafe, kiwisolver, joblib, idna, fonttools, cycler, colorama, charset-normalizer, certifi, attrs, annotated-types, tqdm, scipy, requests, PyWavelets, python-dateutil, pydantic-core, jinja2, contourpy, pydantic, pandas, matplotlib, imagehash, visions, seaborn, phik, missingno, pandas-profiling
#   Attempting uninstall: missingno
#     Found existing installation: missingno 0.5.2
#     Uninstalling missingno-0.5.2:
#       Successfully uninstalled missingno-0.5.2
# Successfully installed Pillow-10.4.0 PyWavelets-1.6.0 PyYAML-6.0.1 annotated-types-0.7.0 attrs-23.2.0 certifi-2024.7.4 charset-normalizer-3.3.2 colorama-0.4.6 contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 htmlmin-0.1.12 idna-3.7 imagehash-4.3.1 jinja2-3.1.4 joblib-1.1.1 kiwisolver-1.4.5 markupsafe-2.1.5 matplotlib-3.9.1 missingno-0.5.2 multimethod-1.12 networkx-3.3 numpy-2.0.1 packaging-24.1 pandas-2.2.2 pandas-profiling-3.2.0 phik-0.12.4 pydantic-2.8.2 pydantic-core-2.20.1 pyparsing-3.1.2 python-dateutil-2.9.0.post0 pytz-2024.1 requests-2.32.3 scipy-1.14.0 seaborn-0.13.2 six-1.16.0 tangled-up-in-unicode-0.2.0 tqdm-4.66.4 typing-extensions-4.12.2 tzdata-2024.1 urllib3-2.2.2 visions-0.7.4
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script htmlmin.exe is installed in 'C:\Users\gabri\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\gabri\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\gabri\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'C:\Users\gabri\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tqdm.exe is installed in 'C:\Users\gabri\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pandas_profiling.exe is installed in 'C:\Users\gabri\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-learn 1.5.1 requires joblib>=1.2.0, but you have joblib 1.1.1 which is incompatible.
# streamlit 1.32.0 requires numpy<2,>=1.19.3, but you have numpy 2.0.1 which is incompatible.
# streamlit 1.32.0 requires packaging<24,>=16.8, but you have packaging 24.1 which is incompatible.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pydantic-settings
#   Using cached pydantic_settings-2.4.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: pydantic>=2.7.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pydantic-settings) (2.8.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\programdata\anaconda3\lib\site-packages (from pydantic-settings) (0.21.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pydantic>=2.7.0->pydantic-settings) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pydantic>=2.7.0->pydantic-settings) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pydantic>=2.7.0->pydantic-settings) (4.12.2)
# Using cached pydantic_settings-2.4.0-py3-none-any.whl (23 kB)
# Installing collected packages: pydantic-settings
# Successfully installed pydantic-settings-2.4.0
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pydantic==1.10.8
#   Using cached pydantic-1.10.8-py3-none-any.whl.metadata (146 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pydantic==1.10.8) (4.12.2)
# Using cached pydantic-1.10.8-py3-none-any.whl (157 kB)
# Installing collected packages: pydantic
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.8.2
#     Uninstalling pydantic-2.8.2:
#       Successfully uninstalled pydantic-2.8.2
# Successfully installed pydantic-1.10.8
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pydantic-settings 2.4.0 requires pydantic>=2.7.0, but you have pydantic 1.10.8 which is incompatible.

# %%
# %pip install pandas-profiling==3.1.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas-profiling==3.1.0
#   Using cached pandas_profiling-3.1.0-py2.py3-none-any.whl.metadata (23 kB)
# Collecting joblib~=1.0.1 (from pandas-profiling==3.1.0)
#   Using cached joblib-1.0.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pandas-profiling==3.1.0) (1.14.0)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pandas-profiling==3.1.0) (2.2.2)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pandas-profiling==3.1.0) (3.9.1)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pandas-profiling==3.1.0) (1.10.8)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pandas-profiling==3.1.0) (6.0.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pandas-profiling==3.1.0) (3.1.4)
# Collecting markupsafe~=2.0.1 (from pandas-profiling==3.1.0)
#   Using cached MarkupSafe-2.0.1-py3-none-any.whl
# Requirement already satisfied: visions==0.7.4 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling==3.1.0) (0.7.4)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pandas-profiling==3.1.0) (2.0.1)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pandas-profiling==3.1.0) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pandas-profiling==3.1.0) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pandas-profiling==3.1.0) (0.12.4)
# Collecting tangled-up-in-unicode==0.1.0 (from pandas-profiling==3.1.0)
#   Using cached tangled_up_in_unicode-0.1.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: requests>=2.24.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pandas-profiling==3.1.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pandas-profiling==3.1.0) (4.66.4)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pandas-profiling==3.1.0) (0.13.2)
# Requirement already satisfied: multimethod>=1.4 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pandas-profiling==3.1.0) (1.12)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling==3.1.0) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling==3.1.0) (3.3)
# Requirement already satisfied: imagehash in c:\users\gabri\appdata\roaming\python\python312\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling==3.1.0) (4.3.1)
# Requirement already satisfied: Pillow in c:\users\gabri\appdata\roaming\python\python312\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling==3.1.0) (10.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling==3.1.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling==3.1.0) (2024.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pydantic>=1.8.1->pandas-profiling==3.1.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from requests>=2.24.0->pandas-profiling==3.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from requests>=2.24.0->pandas-profiling==3.1.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from requests>=2.24.0->pandas-profiling==3.1.0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from requests>=2.24.0->pandas-profiling==3.1.0) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\gabri\appdata\roaming\python\python312\site-packages (from tqdm>=4.48.2->pandas-profiling==3.1.0) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling==3.1.0) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\users\gabri\appdata\roaming\python\python312\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling==3.1.0) (1.6.0)
# Using cached pandas_profiling-3.1.0-py2.py3-none-any.whl (261 kB)
# Using cached tangled_up_in_unicode-0.1.0-py3-none-any.whl (3.1 MB)
# Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# Installing collected packages: tangled-up-in-unicode, markupsafe, joblib, pandas-profiling
#   Attempting uninstall: tangled-up-in-unicode
#     Found existing installation: tangled-up-in-unicode 0.2.0
#     Uninstalling tangled-up-in-unicode-0.2.0:
#       Successfully uninstalled tangled-up-in-unicode-0.2.0
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.1.5
#     Uninstalling MarkupSafe-2.1.5:
#       Successfully uninstalled MarkupSafe-2.1.5
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.1
#     Uninstalling joblib-1.1.1:
#       Successfully uninstalled joblib-1.1.1
#   Attempting uninstall: pandas-profiling
#     Found existing installation: pandas-profiling 3.2.0
#     Uninstalling pandas-profiling-3.2.0:
#       Successfully uninstalled pandas-profiling-3.2.0
# Successfully installed joblib-1.0.1 markupsafe-2.0.1 pandas-profiling-3.1.0 tangled-up-in-unicode-0.1.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script pandas_profiling.exe is installed in 'C:\Users\gabri\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-learn 1.5.1 requires joblib>=1.2.0, but you have joblib 1.0.1 which is incompatible.
# imbalanced-learn 0.12.3 requires joblib>=1.1.1, but you have joblib 1.0.1 which is incompatible.
# streamlit 1.32.0 requires numpy<2,>=1.19.3, but you have numpy 2.0.1 which is incompatible.
# streamlit 1.32.0 requires packaging<24,>=16.8, but you have packaging 24.1 which is incompatible.
# werkzeug 3.0.3 requires MarkupSafe>=2.1.1, but you have markupsafe 2.0.1 which is incompatible.

# %%
# %pip install ydata-profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ydata-profiling
#   Using cached ydata_profiling-4.9.0-py2.py3-none-any.whl.metadata (20 kB)
# Collecting scipy<1.14,>=1.4.1 (from ydata-profiling)
#   Using cached scipy-1.13.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: matplotlib<3.10,>=3.5 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from ydata-profiling) (3.9.1)
# Collecting pydantic>=2 (from ydata-profiling)
#   Using cached pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from ydata-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from ydata-profiling) (3.1.4)
# Collecting visions<0.7.7,>=0.7.5 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling)
#   Using cached visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# Collecting numpy<2,>=1.16.0 (from ydata-profiling)
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from ydata-profiling) (4.66.4)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in d:\programdata\anaconda3\lib\site-packages (from ydata-profiling) (0.14.2)
# Collecting typeguard<5,>=3 (from ydata-profiling)
#   Using cached typeguard-4.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from ydata-profiling) (4.3.1)
# Collecting wordcloud>=1.9.1 (from ydata-profiling)
#   Using cached wordcloud-1.9.3-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Using cached dacite-1.8.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numba<1,>=0.56.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from ydata-profiling) (0.60.0)
# Requirement already satisfied: PyWavelets in c:\users\gabri\appdata\roaming\python\python312\site-packages (from imagehash==4.3.1->ydata-profiling) (1.6.0)
# Requirement already satisfied: pillow in c:\users\gabri\appdata\roaming\python\python312\site-packages (from imagehash==4.3.1->ydata-profiling) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from numba<1,>=0.56.0->ydata-profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.0.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pydantic>=2->ydata-profiling) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from pydantic>=2->ydata-profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2024.7.4)
# Requirement already satisfied: patsy>=0.5.6 in d:\programdata\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.6)
# Requirement already satisfied: colorama in c:\users\gabri\appdata\roaming\python\python312\site-packages (from tqdm<5,>=4.48.2->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\gabri\appdata\roaming\python\python312\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (3.3)
# Requirement already satisfied: six in c:\users\gabri\appdata\roaming\python\python312\site-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# Using cached ydata_profiling-4.9.0-py2.py3-none-any.whl (356 kB)
# Using cached dacite-1.8.1-py3-none-any.whl (14 kB)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Using cached pydantic-2.8.2-py3-none-any.whl (423 kB)
# Using cached scipy-1.13.1-cp312-cp312-win_amd64.whl (45.9 MB)
# Using cached typeguard-4.3.0-py3-none-any.whl (35 kB)
# Using cached visions-0.7.6-py3-none-any.whl (104 kB)
# Using cached wordcloud-1.9.3-cp312-cp312-win_amd64.whl (301 kB)
# Installing collected packages: typeguard, numpy, dacite, scipy, pydantic, visions, wordcloud, ydata-profiling
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.1
#     Uninstalling numpy-2.0.1:
#       Successfully uninstalled numpy-2.0.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.0
#     Uninstalling scipy-1.14.0:
#       Successfully uninstalled scipy-1.14.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.8
#     Uninstalling pydantic-1.10.8:
#       Successfully uninstalled pydantic-1.10.8
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.4
#     Uninstalling visions-0.7.4:
#       Successfully uninstalled visions-0.7.4
# Successfully installed dacite-1.8.1 numpy-1.26.4 pydantic-2.8.2 scipy-1.13.1 typeguard-4.3.0 visions-0.7.6 wordcloud-1.9.3 ydata-profiling-4.9.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'C:\Users\gabri\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script wordcloud_cli.exe is installed in 'C:\Users\gabri\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pandas_profiling.exe and ydata_profiling.exe are installed in 'C:\Users\gabri\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.1.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.
# scikit-learn 1.5.1 requires joblib>=1.2.0, but you have joblib 1.0.1 which is incompatible.
# imbalanced-learn 0.12.3 requires joblib>=1.1.1, but you have joblib 1.0.1 which is incompatible.
# streamlit 1.32.0 requires packaging<24,>=16.8, but you have packaging 24.1 which is incompatible.

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
import ydata_profiling as pp

import sidetable
import pandas_profiling
import missingno as msno
from ipywidgets import interact, widgets

from sklearn import datasets
from sklearn.preprocessing import scale, minmax_scale, power_transform

# %%
sns.set_theme(
    context='talk',
    style='ticks',
    font_scale=.8,
    rc={
        'figure.figsize': (12, 8)
    }
)

# %%
def list_attributes(obj):
    """Lista atributos e funções de um objeto"""
    return [attr for attr in obj.__dir__() if not attr.startswith('_')]

# %%
# Read titanic dataset
df = pd.read_csv('https://raw.githubusercontent.com/adamerose/datasets/master/titanic.csv')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# Valores duplicados

# %%
df.
